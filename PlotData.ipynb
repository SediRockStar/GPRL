# %%
import matplotlib.pyplot as plt
import numpy as np
avg = [147.866, 107.84, 103.782, 195.556, 137.986, 185.766, 154.61, 143.782, 142.808, 200, 200, 200]
std = np.array([35.96023634, 33.35294528, 27.29753022, 12.46403846, 30.78739021, 21.69306545, 29.82460528, 30.91146446, 31.80377492, 0, 0, 0])
kernel=["Matern","RBF", "RationalQuadratic","ExpSineSquared"]

#plt.figure(figsize=(7,5))
for i in range(0, len(avg), 3):
    x = [10, 25, 50]
    y = [avg[i], avg[i+1], avg[i+2]]
    yerr = [std[i], std[i+1], std[i+2]]
    plt.errorbar(x, y, yerr=yerr, fmt='o-', capsize=2, label=f'{kernel[int(i/3)]}')

plt.xlabel('Number of Iterations (T)')
plt.ylabel('Number of Steps')
#plt.title('Graph')
plt.legend()
#plt.show()
plt.savefig("plot.jpg")
